# %% [markdown]
# ![About%20Me%20Babji%20E.%20Manohar.PNG](attachment:About%20Me%20Babji%20E.%20Manohar.PNG)

# %% [markdown]
# Data Description:
# ---
# ```
# Image Classification:
# --------------------
# Images are classified into 10 classes, each class has set of images in a separate folder.
#
# The Image data description: Data has been augumented for generalization.
# ---------------------------
# 	Airplanes         - 828 RGB images with resolution of 400x160 approx.
# 	Background_Google - 759 RGB images with resolution of 500x300 approx.
# 	Bonsai            - 708 RGB images with resolution of 300x280 approx.
# 	Car_side          - 712 RGB images with resolution of 300x197 approx.
# 	Faces             - 730 RGB images with resolution of 500x340 approx.
# 	Faces_easy        - 731 RGB images with resolution of 280x320 approx.
# 	Grand_Piano       - 689 RGB images with resolution of 300x280 approx.
# 	Leopards          - 775 RGB images with resolution of 192x128 approx.
# 	Motorbikes        - 798 RGB images with resolution of 260x140 approx.
# 	Watch             - 823 RGB images with resolution of 300x220 approx.
# ```

# %% [markdown]
# Class Count:
# ---
# ```
# |   Classes           : Count of Data |
# |-------------------------------------|
# |   car_side          :      712      |
# |   watch             :      823      |
# |   Faces_easy        :      731      |
# |   airplanes         :      828      |
# |   Leopards          :      775      |
# |   Motorbikes        :      798      |
# |   BACKGROUND_Google :      759      |
# |   Faces             :      730      |
# |   bonsai            :      708      |
# |   grand_piano       :      689      |
#
# ```

# %% [markdown]
# Train and Validation Split:
# ----
# ```
# Preprocesed the INPUT SHAPE = (224, 224, 3)
# 80% Training Data
# 20% Validation Data
# ---------------------------
# Found 6046 images belonging to 10 classes.   < Train Data >
# Found 1506 images belonging to 10 classes. < Validation Data >
# ```

# %% [markdown]
# Prebuilt Model: MobileNetV2 from Keras
# ----
# ```
# MobileNetV2(include_top=False,weights='imagenet', input_shape = (224, 224, 3))
#
# nb_classes=10, layer.trainable = True
#
# model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='Adadelta')
# ```

# %% [markdown]
# # [The MobileNetV2 Architecture:](https://arxiv.org/abs/1801.04381)
# <br>
#
# ![MobileNetV2_Archicecture.PNG](attachment:MobileNetV2_Archicecture.PNG)

# %% [markdown]
# MobileNetV2 Architecture Flow:
# ---
# <br>
#
# ![MobileNetV2.png](attachment:MobileNetV2.png)

# %% [markdown]
# Training the complete 'MobileNetV2 Model' on the Data:
# ----
# ```
# Epoch 1/50
# 189/188 [==============================] - 2048s 11s/step -  loss    : 0.2440 - acc    : 0.9272 -
#                                                              val_loss: 0.5232 - val_acc: 0.9064
# Epoch 2/50
# 189/188 [==============================] - 135s 714ms/step - loss    : 0.1348 - acc    : 0.9648 -
#                                                              val_loss: 2.7201 - val_acc: 0.6534
# Epoch 3/50
# 189/188 [==============================] - 138s 730ms/step - loss    : 0.1058 - acc    : 0.9704 -
#                                                              val_loss: 2.1763 - val_acc: 0.7377
# Epoch 4/50
# 189/188 [==============================] - 137s 725ms/step - loss    : 0.0648 - acc    : 0.9815 -
#                                                              val_loss: 0.7205 - val_acc: 0.8831
# Epoch 5/50
# 189/188 [==============================] - 137s 726ms/step - loss    : 0.0764 - acc    : 0.9795 -
#                                                              val_loss: 1.2289 - val_acc: 0.8367
# Epoch 6/50
# 189/188 [==============================] - 138s 731ms/step - loss    : 0.0469 - acc    : 0.9853 -
#                                                              val_loss: 1.0991 - val_acc: 0.8313
# Epoch 7/50
# 189/188 [==============================] - 137s 727ms/step - loss    : 0.0471 - acc    : 0.9866 -
#                                                              val_loss: 1.7319 - val_acc: 0.7689
# Epoch 8/50
# 189/188 [==============================] - 137s 725ms/step - loss    : 0.0457 - acc    : 0.9887 -
#                                                              val_loss: 3.1551 - val_acc: 0.6846
# Epoch 9/50
# 189/188 [==============================] - 136s 721ms/step - loss    : 0.0489 - acc    : 0.9854 -
#                                                              val_loss: 3.5852 - val_acc: 0.5525
# Epoch 10/50
# 189/188 [==============================] - 136s 719ms/step - loss    : 0.0293 - acc    : 0.9924 -
#                                                              val_loss: 0.5320 - val_acc: 0.8971
# Epoch 11/50
# 189/188 [==============================] - 136s 720ms/step - loss    : 0.0233 - acc    : 0.9929 -
#                                                              val_loss: 0.2701 - val_acc: 0.9555
# Epoch 12/50
# 189/188 [==============================] - 136s 720ms/step - loss    : 0.0377 - acc    : 0.9894 -
#                                                              val_loss: 0.8323 - val_acc: 0.8858
# Epoch 13/50
# 189/188 [==============================] - 136s 720ms/step - loss    : 0.0275 - acc    : 0.9927 -
#                                                              val_loss: 0.3046 - val_acc: 0.9449
# Epoch 14/50
# 189/188 [==============================] - 136s 721ms/step - loss    : 0.0252 - acc    : 0.9926 -
#                                                              val_loss: 0.4466 - val_acc: 0.9283
# Epoch 15/50
# 189/188 [==============================] - 136s 717ms/step - loss    : 0.0243 - acc    : 0.9924 -
#                                                              val_loss: 0.5919 - val_acc: 0.9031
# Epoch 16/50
# 189/188 [==============================] - 136s 717ms/step - loss    : 0.0287 - acc    : 0.9932 -
#                                                              val_loss: 0.3218 - val_acc: 0.9462
# Epoch 17/50
# 189/188 [==============================] - 137s 723ms/step - loss    : 0.0185 - acc    : 0.9942 -
#                                                              val_loss: 0.2267 - val_acc: 0.9595
# Epoch 18/50
# 189/188 [==============================] - 135s 712ms/step - loss    : 0.0234 - acc    : 0.9927 -
#                                                              val_loss: 0.2679 - val_acc: 0.9515
# Epoch 19/50
# 189/188 [==============================] - 136s 719ms/step - loss    : 0.0132 - acc    : 0.9962 -
#                                                              val_loss: 0.3340 - val_acc: 0.9535
# Epoch 20/50
# 189/188 [==============================] - 134s 711ms/step - loss    : 0.0153 - acc    : 0.9962 -
#                                                              val_loss: 0.1378 - val_acc: 0.9728
# Epoch 21/50
# 189/188 [==============================] - 134s 711ms/step - loss    : 0.0177 - acc    : 0.9945 -
#                                                              val_loss: 0.2998 - val_acc: 0.9502
# Epoch 22/50
# 189/188 [==============================] - 134s 711ms/step - loss    : 0.0143 - acc    : 0.9959 -
#                                                              val_loss: 0.3885 - val_acc: 0.9409
# Epoch 23/50
# 189/188 [==============================] - 134s 710ms/step - loss    : 0.0121 - acc    : 0.9964 -
#                                                              val_loss: 0.3380 - val_acc: 0.9436
# Epoch 24/50
# 189/188 [==============================] - 135s 717ms/step - loss    : 0.0151 - acc    : 0.9960 -
#                                                              val_loss: 0.1441 - val_acc: 0.9761
# Epoch 25/50
# 189/188 [==============================] - 136s 721ms/step - loss    : 0.0119 - acc    : 0.9967 -
#                                                              val_loss: 0.1928 - val_acc: 0.9714
# Epoch 26/50
# 189/188 [==============================] - 137s 725ms/step - loss    : 0.0145 - acc    : 0.9965 -
#                                                              val_loss: 0.7683 - val_acc: 0.8712
# Epoch 27/50
# 189/188 [==============================] - 136s 718ms/step - loss    : 0.0176 - acc    : 0.9950 -
#                                                              val_loss: 0.2785 - val_acc: 0.9475
# Epoch 28/50
# 189/188 [==============================] - 131s 694ms/step - loss    : 0.0087 - acc    : 0.9970 -
#                                                              val_loss: 0.2326 - val_acc: 0.9635
# Epoch 29/50
# 189/188 [==============================] - 130s 689ms/step - loss    : 0.0081 - acc    : 0.9962 -
#                                                              val_loss: 0.2181 - val_acc: 0.9602
# Epoch 30/50
# 189/188 [==============================] - 130s 689ms/step - loss    : 0.0096 - acc    : 0.9974 -
#                                                              val_loss: 0.2073 - val_acc: 0.9641
# Epoch 31/50
# 189/188 [==============================] - 132s 701ms/step - loss    : 0.0059 - acc    : 0.9982 -
#                                                              val_loss: 0.0963 - val_acc: 0.9854
# Epoch 32/50
# 189/188 [==============================] - 134s 712ms/step - loss    : 0.0087 - acc    : 0.9969 -
#                                                              val_loss: 0.1460 - val_acc: 0.9675
# Epoch 33/50
# 189/188 [==============================] - 134s 710ms/step - loss    : 0.0083 - acc    : 0.9979 -
#                                                              val_loss: 0.1308 - val_acc: 0.9814
# Epoch 34/50
# 189/188 [==============================] - 135s 713ms/step - loss    : 0.0094 - acc    : 0.9974 -
#                                                              val_loss: 0.0600 - val_acc: 0.9880
# Epoch 35/50
# 189/188 [==============================] - 136s 718ms/step - loss    : 0.0107 - acc    : 0.9969 -
#                                                              val_loss: 0.0615 - val_acc: 0.9874
# Epoch 36/50
# 189/188 [==============================] - 134s 710ms/step - loss    : 0.0111 - acc    : 0.9970 -
#                                                              val_loss: 0.1140 - val_acc: 0.9827
# Epoch 37/50
# 189/188 [==============================] - 136s 719ms/step - loss    : 0.0117 - acc    : 0.9962 -
#                                                              val_loss: 0.0642 - val_acc: 0.9827
# Epoch 38/50
# 189/188 [==============================] - 136s 720ms/step - loss    : 0.0060 - acc    : 0.9975 -
#                                                              val_loss: 0.1634 - val_acc: 0.9748
# Epoch 39/50
# 189/188 [==============================] - 136s 720ms/step - loss    : 0.0110 - acc    : 0.9969 -
#                                                              val_loss: 0.1623 - val_acc: 0.9668
# Epoch 40/50
# 189/188 [==============================] - 136s 721ms/step - loss    : 0.0066 - acc    : 0.9979 -
#                                                              val_loss: 0.1197 - val_acc: 0.9774
# Epoch 41/50
# 189/188 [==============================] - 136s 722ms/step - loss    : 0.0139 - acc    : 0.9955 -
#                                                              val_loss: 0.1069 - val_acc: 0.9807
# Epoch 42/50
# 189/188 [==============================] - 137s 725ms/step - loss    : 0.0090 - acc    : 0.9969 -
#                                                              val_loss: 0.2865 - val_acc: 0.9655
# Epoch 43/50
# 189/188 [==============================] - 137s 724ms/step - loss    : 0.0068 - acc    : 0.9983 -
#                                                              val_loss: 0.2299 - val_acc: 0.9714
# Epoch 44/50
# 189/188 [==============================] - 136s 721ms/step - loss    : 0.0081 - acc    : 0.9972 -
#                                                              val_loss: 0.1807 - val_acc: 0.9754
# Epoch 45/50
# 189/188 [==============================] - 136s 719ms/step - loss    : 0.0120 - acc    : 0.9965 -
#                                                              val_loss: 0.0481 - val_acc: 0.9920
# Epoch 46/50
# 189/188 [==============================] - 136s 721ms/step - loss    : 0.0049 - acc    : 0.9987 -
#                                                              val_loss: 0.0395 - val_acc: 0.9900
# Epoch 47/50
# 189/188 [==============================] - 137s 724ms/step - loss    : 0.0090 - acc    : 0.9972 -
#                                                              val_loss: 0.0441 - val_acc: 0.9874
# Epoch 48/50
# 189/188 [==============================] - 137s 724ms/step - loss    : 0.0078 - acc    : 0.9970 -
#                                                              val_loss: 0.0646 - val_acc: 0.9880
# Epoch 49/50
# 189/188 [==============================] - 137s 727ms/step - loss    : 0.0129 - acc    : 0.9959 -
#                                                              val_loss: 0.2043 - val_acc: 0.9615
# Epoch 50/50
# 189/188 [==============================] - 136s 722ms/step - loss    : 0.0117 - acc    : 0.9957 -
#                                                              val_loss: 0.1288 - val_acc: 0.9788
# ```

# %% [markdown]
# Time of Execution for Training:
# ---
# ```
# First Epoch             : 2048   Sec.
#
# Avg Per Epoch           :  135.5 Sec. (Except first Epoch)
#
# Total Time of Execution : 8688   Sec. (144.8 min) for 50 Epochs
# ```

# %% [markdown]
# Learning Losses and Accuracies:
# ---
#
# ![MobileNetV2%20Accuracy%20Result.png](attachment:MobileNetV2%20Accuracy%20Result.png)

# %% [markdown]
# ```
# ----------------------------
# Maximum Validation Accuracy: 99.20 %  !!!
# ----------------------------
# Epoch 45/50
# 189/188 [==============================] - 136s 719ms/step - loss    : 0.0120 - acc    : 0.9965 -
#                                                              val_loss: 0.0481 - val_acc: 0.9920
# ```
